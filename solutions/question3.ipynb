# %%
# Included libraries
import numpy as np
import pandas as pd
import talib as ta

# %%
# Load CSV
df = pd.read_csv("../data/MarketData.csv", header=[3,4,5,6])
df.columns = df.columns.get_level_values(1) # Truncate to 1 header
df.rename(columns={df.columns[0]:"Date"}, inplace=True) # This is a bit inefficient as this name exists in level 0...
df.rename(columns={'LMCADS03 Comdty':'Copper',
                   'LMAHDS03 Comdty':'Aluminium',
                   'LMZSDS03 Comdty':'Zinc',
                   'LMPBDS03 Comdty':'Lead',
                   'LMSNDS03 Comdty':'Tin',
                   'CL1 Comdty':'CL1'},
                    inplace=True)
df.head(5)
# Out:
#          Date  Copper  Aluminium    Zinc    Lead    Tin    CL1
# 0  01/01/2010  7375.0     2230.0  2560.0  2432.0  16950  79.36
# 1  04/01/2010  7500.0     2267.0  2574.0  2515.0  17450  81.51
# 2  05/01/2010  7485.0     2302.0  2575.0  2522.5  17375  81.77
# 3  06/01/2010  7660.0     2377.0  2718.0  2680.0  17825  83.18
# 4  07/01/2010  7535.0     2310.0  2607.0  2599.0  17475  82.66

# %%
# Filter all data except 2021 Zinc and Copper
df = df[['Date', 'Copper', 'Zinc']]
df['Date'] = pd.to_datetime(df['Date'], format="%d/%m/%Y") # Convert to pd datetime friendly format
df = df[(df['Date'] > '2019-12-31') & (df['Date'] < '2022-01-01')]
df = df.reset_index(drop=True) # Reset index after truncation
df.tail(5)
# Out:
#           Date  Copper    Zinc
# 518 2021-12-27  9568.0  3519.0
# 519 2021-12-28  9568.0  3519.0
# 520 2021-12-29  9680.5  3513.0
# 521 2021-12-30  9691.5  3532.5
# 522 2021-12-31  9720.5  3534.0

# %%
# Function to deal with TA calculations
def ta_functions(input):
   input['RSI_Copper'] = ta.RSI(input['Copper']) # RSI Copper

   # MACD Copper
   input['MACD_Copper'], input['MACD_sig_Copper'], input['MACD_hist_Copper'] = ta.MACD(input['Copper'], fastperiod=12, slowperiod=26, signalperiod=9)

   input['RSI_Zinc'] = ta.RSI(input['Zinc']) # RSI Zinc

   # MACD Zinc
   input['MACD_Zinc'], input['MACD_sig_Zinc'], input['MACD_hist_Zinc'] = ta.MACD(input['Zinc'], fastperiod=12, slowperiod=26, signalperiod=9)

   return input

# %%
# Pass dataframe through TA calculations and add columns
df = ta_functions(df)
df.tail(5)
# Out:
#           Date  Copper    Zinc  RSI_Copper  MACD_Copper  MACD_sig_Copper  \
# 518 2021-12-27  9568.0  3519.0   51.692406    -2.500190       -20.259043
# 519 2021-12-28  9568.0  3519.0   51.692406     0.815513       -16.044131
# 520 2021-12-29  9680.5  3513.0   56.618811    12.378352       -10.359635
# 521 2021-12-30  9691.5  3532.5   57.079706    22.173985        -3.852911
# 522 2021-12-31  9720.5  3534.0   58.336450    31.909321         3.299536
#
#      MACD_hist_Copper   RSI_Zinc  MACD_Zinc  MACD_sig_Zinc  MACD_hist_Zinc
# 518         17.758853  66.260897  66.849430      41.187284       25.662145
# 519         16.859645  66.260897  69.361656      46.822159       22.539497
# 520         22.737987  65.418907  70.060845      51.469896       18.590949
# 521         26.026896  66.891416  71.365785      55.449074       15.916711
# 522         28.609786  67.007795  71.694546      58.698168       12.996378

# %%
# The following blocks were imported from question 2,
# in order to populate an SQL table with async inserts.
# This time a logging mechanism is also added based on the session context manager

# Included libraries
from __future__ import annotations
from asyncio import current_task, run
from contextlib import asynccontextmanager
from collections.abc import AsyncGenerator
import logging

# SQL
from sqlalchemy import Column, MetaData, select, String, Table, event, text, create_engine, insert, update, delete
from sqlalchemy.engine import Engine
from sqlalchemy.ext.asyncio import create_async_engine, AsyncSession, async_scoped_session
from sqlalchemy.orm import sessionmaker

# %%
engine = create_async_engine('sqlite+aiosqlite://', echo=True) # SQL engine
meta = MetaData() # Metadata for SQL session - used to generate table object later
maker = sessionmaker(engine, class_=AsyncSession)
scope = async_scoped_session(maker, current_task)
tablename = 'MarketData'

# %%
# Generate sessions via contextmanager for asynchronous function calls.
# The point of this is to allow multithreading/concurrency of DB I/O operations
@asynccontextmanager
async def get_session():
   async with scope() as session:
      yield session # Yield instead of return to pick up where it left off on every function call

# %%
# Not a 100% about this, I think in the output for the cell below with echo=True on the engine it shows
# multiple instances of async inserts being called, however I am not certain as to why the logging message
# does not show.

# Decorator that wraps the async insert function with a logging routine
@asynccontextmanager
async def logger(f):
   def wrap(*arguments, **kwarguments): # Wrapper takes in more than 1 arg
      logging.log(msg="IO start", level=logging.DEBUG)
      f(*arguments, **kwarguments)
   return wrap # Return wrapped function

# %%
# Asynchronous SQL CRUD operations
async def main():

   # Obtain a session variable for each instance
   async with get_session() as session:

      conn = await session.connection()

      # CSV to SQL
      await conn.run_sync(
         lambda sync_conn: df.to_sql(tablename, con=sync_conn)
      )

      # Define SQL table object
      marketdata = await conn.run_sync(
         lambda conn: Table(tablename, meta, autoload_with=conn, sqlite_autoincrement=True)
      )

      # Read table
      async with engine.connect() as conn:
         result = await conn.execute(select(marketdata))
         print(result.fetchall())

      # Permanently store changes to database
      await session.commit()

# Launch asynchronous task
await main()
# Out:
# 2024-02-18 19:40:46,715 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-02-18 19:40:46,722 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("MarketData")
# 2024-02-18 19:40:46,724 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-02-18 19:40:46,728 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("MarketData")
# 2024-02-18 19:40:46,731 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-02-18 19:40:46,736 INFO sqlalchemy.engine.Engine
# CREATE TABLE "MarketData" (
# 	"index" BIGINT,
# 	"Date" DATETIME,
# 	"Copper" FLOAT,
# 	"Zinc" FLOAT,
# 	"RSI_Copper" FLOAT,
# 	"MACD_Copper" FLOAT,
# 	"MACD_sig_Copper" FLOAT,
# 	"MACD_hist_Copper" FLOAT,
# 	"RSI_Zinc" FLOAT,
# 	"MACD_Zinc" FLOAT,
# 	"MACD_sig_Zinc" FLOAT,
# 	"MACD_hist_Zinc" FLOAT
# )
#
#
# 2024-02-18 19:40:46,737 INFO sqlalchemy.engine.Engine [no key 0.00192s] ()
# 2024-02-18 19:40:46,741 INFO sqlalchemy.engine.Engine CREATE INDEX "ix_MarketData_index" ON "MarketData" ("index")
# 2024-02-18 19:40:46,742 INFO sqlalchemy.engine.Engine [no key 0.00118s] ()
# 2024-02-18 19:40:46,759 INFO sqlalchemy.engine.Engine INSERT INTO "MarketData" ("index", "Date", "Copper", "Zinc", "RSI_Copper", "MACD_Copper", "MACD_sig_Copper", "MACD_hist_Copper", "RSI_Zinc", "MACD_Zinc", "MACD_sig_Zinc", "MACD_hist_Zinc") VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2024-02-18 19:40:46,761 INFO sqlalchemy.engine.Engine [generated in 0.00926s] [(0, '2020-01-01 00:00:00.000000', 6174.0, 2272.0, None, None, None, None, None, None, None, None), (1, '2020-01-02 00:00:00.000000', 6188.0, 2310.0, None, None, None, None, None, None, None, None), (2, '2020-01-03 00:00:00.000000', 6129.5, 2306.0, None, None, None, None, None, None, None, None), (3, '2020-01-06 00:00:00.000000', 6138.5, 2324.5, None, None, None, None, None, None, None, None), (4, '2020-01-07 00:00:00.000000', 6149.0, 2346.0, None, None, None, None, None, None, None, None), (5, '2020-01-08 00:00:00.000000', 6178.0, 2403.0, None, None, None, None, None, None, None, None), (6, '2020-01-09 00:00:00.000000', 6180.0, 2377.0, None, None, None, None, None, None, None, None), (7, '2020-01-10 00:00:00.000000', 6198.0, 2378.0, None, None, None, None, None, None, None, None)  ... displaying 10 of 523 total bound parameter sets ...  (521, '2021-12-30 00:00:00.000000', 9691.5, 3532.5, 57.07970571162615, 22.173984763534463, -3.852910836224254, 26.026895599758717, 66.89141635795187, 71.36578485724795, 55.44907385004817, 15.916711007199773), (522, '2021-12-31 00:00:00.000000', 9720.5, 3534.0, 58.33645024238745, 31.90932129628709, 3.2995355902780155, 28.609785706009074, 67.00779467133343, 71.69454612192158, 58.69816830442285, 12.996377817498725)]
# 2024-02-18 19:40:46,766 INFO sqlalchemy.engine.Engine SELECT name FROM sqlite_master WHERE type='table' AND name NOT LIKE 'sqlite~_%' ESCAPE '~' ORDER BY name
# 2024-02-18 19:40:46,768 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-02-18 19:40:46,772 INFO sqlalchemy.engine.Engine PRAGMA main.table_xinfo("MarketData")
# 2024-02-18 19:40:46,774 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-02-18 19:40:46,777 INFO sqlalchemy.engine.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = ? AND type in ('table', 'view')
# 2024-02-18 19:40:46,779 INFO sqlalchemy.engine.Engine [raw sql] ('MarketData',)
# 2024-02-18 19:40:46,783 INFO sqlalchemy.engine.Engine PRAGMA main.foreign_key_list("MarketData")
# 2024-02-18 19:40:46,784 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-02-18 19:40:46,788 INFO sqlalchemy.engine.Engine PRAGMA temp.foreign_key_list("MarketData")
# 2024-02-18 19:40:46,789 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-02-18 19:40:46,794 INFO sqlalchemy.engine.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = ? AND type in ('table', 'view')
# 2024-02-18 19:40:46,796 INFO sqlalchemy.engine.Engine [raw sql] ('MarketData',)
# 2024-02-18 19:40:46,801 INFO sqlalchemy.engine.Engine PRAGMA main.index_list("MarketData")
# 2024-02-18 19:40:46,802 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-02-18 19:40:46,806 INFO sqlalchemy.engine.Engine PRAGMA main.index_info("ix_MarketData_index")
# 2024-02-18 19:40:46,808 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-02-18 19:40:46,812 INFO sqlalchemy.engine.Engine PRAGMA main.index_list("MarketData")
# 2024-02-18 19:40:46,814 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-02-18 19:40:46,817 INFO sqlalchemy.engine.Engine PRAGMA main.index_info("ix_MarketData_index")
# 2024-02-18 19:40:46,818 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-02-18 19:40:46,822 INFO sqlalchemy.engine.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = ? AND type in ('table', 'view')
# 2024-02-18 19:40:46,824 INFO sqlalchemy.engine.Engine [raw sql] ('MarketData',)
# 2024-02-18 19:40:46,832 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-02-18 19:40:46,834 INFO sqlalchemy.engine.Engine SELECT "MarketData"."index", "MarketData"."Date", "MarketData"."Copper", "MarketData"."Zinc", "MarketData"."RSI_Copper", "MarketData"."MACD_Copper", "MarketData"."MACD_sig_Copper", "MarketData"."MACD_hist_Copper", "MarketData"."RSI_Zinc", "MarketData"."MACD_Zinc", "MarketData"."MACD_sig_Zinc", "MarketData"."MACD_hist_Zinc"
# FROM "MarketData"
# 2024-02-18 19:40:46,836 INFO sqlalchemy.engine.Engine [generated in 0.00385s] ()
# [(0, datetime.datetime(2020, 1, 1, 0, 0), 6174.0, 2272.0, None, None, None, None, None, None, None, None), (1, datetime.datetime(2020, 1, 2, 0, 0), 6188.0, 2310.0, None, None, None, None, None, None, None, None), (2, datetime.datetime(2020, 1, 3, 0, 0), 6129.5, 2306.0, None, None, None, None, None, None, None, None), (3, datetime.datetime(2020, 1, 6, 0, 0), 6138.5, 2324.5, None, None, None, None, None, None, None, None), (4, datetime.datetime(2020, 1, 7, 0, 0), 6149.0, 2346.0, None, None, None, None, None, None, None, None), (5, datetime.datetime(2020, 1, 8, 0, 0), 6178.0, 2403.0, None, None, None, None, None, None, None, None), (6, datetime.datetime(2020, 1, 9, 0, 0), 6180.0, 2377.0, None, None, None, None, None, None, None, None), (7, datetime.datetime(2020, 1, 10, 0, 0), 6198.0, 2378.0, None, None, None, None, None, None, None, None), (8, datetime.datetime(2020, 1, 13, 0, 0), 6290.0, 2378.0, None, None, None, None, None, None, None, None), (9, datetime.datetime(2020, 1, 14, 0, 0), 6302.0, 2373.5, None, None, None, None, None, None, None, None), (10, datetime.datetime(2020, 1, 15, 0, 0), 6287.0, 2385.0, None, None, None, None, None, None, None, None), (11, datetime.datetime(2020, 1, 16, 0, 0), 6277.5, 2422.0, None, None, None, None, None, None, None, None), (12, datetime.datetime(2020, 1, 17, 0, 0), 6273.0, 2429.5, None, None, None, None, None, None, None, None), (13, datetime.datetime(2020, 1, 20, 0, 0), 6259.0, 2444.0, None, None, None, None, None, None, None, None), (14, datetime.datetime(2020, 1, 21, 0, 0), 6160.0, 2454.5, 48.19121447028424, None, None, None, 86.28230616302186, None, None, None), (15, datetime.datetime(2020, 1, 22, 0, 0), 6106.0, 2396.0, 41.89562813202004, None, None, None, 68.99841017488076, None, None, None), (16, datetime.datetime(2020, 1, 23, 0, 0), 5987.0, 2355.0, 31.980619958398858, None, None, None, 59.93642388435357, None, None, None), (17, datetime.datetime(2020, 1, 24, 0, 0), 5926.0, 2341.0, 28.28529496430689, None, None, None, 57.1750832443375, None, None, None), (18, datetime.datetime(2020, 1, 27, 0, 0), 5743.0, 2240.0, 20.59641175063795, None, None, None, 42.10435604622776, None, None, None), (19, datetime.datetime(2020, 1, 28, 0, 0), 5703.0, 2230.0, 19.357754591254604, None, None, None, 40.953343450791415, None, None, None), (20, datetime.datetime(2020, 1, 29, 0, 0), 5641.0, 2211.0, 17.591775314887162, None, None, None, 38.78392613670027, None, None, None), (21, datetime.datetime(2020, 1, 30, 0, 0), 5587.5, 2188.0, 16.216952753646925, None, None, None, 36.27860589893757, None, None, None), (22, datetime.datetime(2020, 1, 31, 0, 0), 5567.0, 2200.0, 15.710304730564387, None, None, None, 38.510385676321484, None, None, None), (23, datetime.datetime(2020, 2, 3, 0, 0), 5525.0, 2146.0, 14.697205511381938, None, None, None, 32.92240583649686, None, None, None), (24, datetime.datetime(2020, 2, 4, 0, 0), 5618.0, 2166.5, 26.06635168871759, None, None, None, 36.67879776816038, None, None, None), (25, datetime.datetime(2020, 2, 5, 0, 0), 5722.0, 2213.0, 36.29205650748584, None, None, None, 44.29859394906758, None, None, None), (26, datetime.datetime(2020, 2, 6, 0, 0), 5735.0, 2207.0, 37.456525201240595, None, None, None, 43.57003434761708, None, None, None), (27, datetime.datetime(2020, 2, 7, 0, 0), 5663.0, 2145.0, 33.77442179124794, None, None, None, 36.82947686377883, None, None, None), (28, datetime.datetime(2020, 2, 10, 0, 0), 5667.0, 2134.0, 34.16164346253224, None, None, None, 35.77208054667967, None, None, None), (29, datetime.datetime(2020, 2, 11, 0, 0), 5745.0, 2148.0, 41.36168014642604, None, None, None, 38.20385698836502, None, None, None), (30, datetime.datetime(2020, 2, 12, 0, 0), 5764.0, 2148.0, 42.996979548048905, None, None, None, 38.20385698836501, None, None, None), (31, datetime.datetime(2020, 2, 13, 0, 0), 5790.0, 2175.0, 45.24720724596344, None, None, None, 43.02847293988323, None, None, None), (32, datetime.datetime(2020, 2, 14, 0, 0), 5760.0, 2149.0, 43.13149918134066, None, None ...
# 2024-02-18 19:40:46,854 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-02-18 19:40:46,858 INFO sqlalchemy.engine.Engine COMMIT
